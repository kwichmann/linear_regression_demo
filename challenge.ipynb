# %% [markdown]
# # Linear regression challenge

# %% [markdown]
# Import libraries.

# %%
import pandas as pd
from sklearn import linear_model
import matplotlib.pyplot as plt

# %% [markdown]
# Read data.

# %%
dataframe = pd.read_csv('challenge_dataset.txt', header=None)
X = dataframe[[0]]
y = dataframe[[1]]

# %% [markdown]
# Split into training and testing sets.

# %%
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/10, random_state = 0)

# %% [markdown]
# Fit linear regression model to trainings set:

# %%
reg = linear_model.LinearRegression()
reg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# Plot results:

# %%
plt.scatter(X_train, y_train, color = "Blue")
plt.plot(X_train, reg.predict(X_train), color = "Red")
plt.show()

# %% [markdown]
# Plot residuals:

# %%
plt.scatter(X_train, y_train - reg.predict(X_train), color = "Blue")
plt.plot([0, 25], [0, 0], color = "Red")
plt.show()

# %% [markdown]
# There seems to be a slight heteroskedastic tendency, but nothing too concerning.
#
# Now let's plot the predictions for the test set (blue) and compare them to the actual values (green):

# %%
plt.scatter(X_test, y_test, color = "Green")
plt.plot(X_train, reg.predict(X_train), color = "Red")
plt.scatter(X_test, reg.predict(X_test), color = "Blue")
plt.show()

# %% [markdown]
# Plot of errors:

# %%
plt.scatter(X_test, reg.predict(X_test) - y_test, color = "Blue")
plt.plot([4, 14], [0, 0], color = "Red")
plt.show()

# %% [markdown]
# Finally, for good measure, the errors in table form:

# %%
reg.predict(X_test) - y_test
# Out:
#            1
# 26 -2.180005
# 84 -1.427128
# 2  -7.396225
# 55  5.153400
# 68  1.706748
# 81  2.155014
# 16 -1.564875
# 78  1.572379
# 54  2.278383
# 66  0.259394
